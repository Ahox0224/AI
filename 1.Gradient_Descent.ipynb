# %% [markdown]
# # 梯度縮減範例

# %%
import numpy as np
import matplotlib.pyplot as plt

# 定義目標函數:y=x^2
def func(x): return np.square(x)

# 定義目標函數一次微分導數:dy/dx=2*x
def dfunc(x): return 2 * x

# %% [markdown]
# ## 定義目標函數 y=x*x

# %%
t = np.arange(-2.0, 4.0, 0.1) #前兩個參數設定的是左右點，第三個是中心點
print(t)
plt.plot(t, func(t), c='b')
plt.show()
# Out:
# [-2.00000000e+00 -1.90000000e+00 -1.80000000e+00 -1.70000000e+00
#  -1.60000000e+00 -1.50000000e+00 -1.40000000e+00 -1.30000000e+00
#  -1.20000000e+00 -1.10000000e+00 -1.00000000e+00 -9.00000000e-01
#  -8.00000000e-01 -7.00000000e-01 -6.00000000e-01 -5.00000000e-01
#  -4.00000000e-01 -3.00000000e-01 -2.00000000e-01 -1.00000000e-01
#   1.77635684e-15  1.00000000e-01  2.00000000e-01  3.00000000e-01
#   4.00000000e-01  5.00000000e-01  6.00000000e-01  7.00000000e-01
#   8.00000000e-01  9.00000000e-01  1.00000000e+00  1.10000000e+00
#   1.20000000e+00  1.30000000e+00  1.40000000e+00  1.50000000e+00
#   1.60000000e+00  1.70000000e+00  1.80000000e+00  1.90000000e+00
#   2.00000000e+00  2.10000000e+00  2.20000000e+00  2.30000000e+00
#   2.40000000e+00  2.50000000e+00  2.60000000e+00  2.70000000e+00
#   2.80000000e+00  2.90000000e+00  3.00000000e+00  3.10000000e+00
#   3.20000000e+00  3.30000000e+00  3.40000000e+00  3.50000000e+00
#   3.60000000e+00  3.70000000e+00  3.80000000e+00  3.90000000e+00]

# %% [markdown]
# ## 定義梯度縮減函數
# ### 梯度：目標函數的一階導數(斜率)
# ### 梯度縮減：往斜率的"反方向"前進
# ### 在epochs次反覆運算中x的更新值
#  x_start: x的起始點
#  df: 目標函數的一階導函數
#  epochs: 反覆運算次數
#  lr: 學習率
#  回傳：x在每次反覆運算後的位置（包括起始點），長度為epochs+1

# %%
def GD(x_start, df, epochs, lr):    
    xs = np.zeros(epochs+1)    
    x = x_start    
    xs[0] = x    
    for i in range(epochs):         
        dx = df(x)        
        # v表示x要改變的幅度        
        v = - dx * lr        
        x += v        
        xs[i+1] = x    
    return xs

# %%
# 起始權重
x_start = 2    
# 執行週期數
epochs = 24 
# 學習率   
lr = 0.24   

t = np.arange(-2.0, 4.0, 0.1)
print(t)

# 梯度下降法 
x = GD(x_start, dfunc, epochs, lr=lr)
print(x)
# Out:
# [-2.00000000e+00 -1.90000000e+00 -1.80000000e+00 -1.70000000e+00
#  -1.60000000e+00 -1.50000000e+00 -1.40000000e+00 -1.30000000e+00
#  -1.20000000e+00 -1.10000000e+00 -1.00000000e+00 -9.00000000e-01
#  -8.00000000e-01 -7.00000000e-01 -6.00000000e-01 -5.00000000e-01
#  -4.00000000e-01 -3.00000000e-01 -2.00000000e-01 -1.00000000e-01
#   1.77635684e-15  1.00000000e-01  2.00000000e-01  3.00000000e-01
#   4.00000000e-01  5.00000000e-01  6.00000000e-01  7.00000000e-01
#   8.00000000e-01  9.00000000e-01  1.00000000e+00  1.10000000e+00
#   1.20000000e+00  1.30000000e+00  1.40000000e+00  1.50000000e+00
#   1.60000000e+00  1.70000000e+00  1.80000000e+00  1.90000000e+00
#   2.00000000e+00  2.10000000e+00  2.20000000e+00  2.30000000e+00
#   2.40000000e+00  2.50000000e+00  2.60000000e+00  2.70000000e+00
#   2.80000000e+00  2.90000000e+00  3.00000000e+00  3.10000000e+00
#   3.20000000e+00  3.30000000e+00  3.40000000e+00  3.50000000e+00
#   3.60000000e+00  3.70000000e+00  3.80000000e+00  3.90000000e+00]
# [2.00000000e+00 1.04000000e+00 5.40800000e-01 2.81216000e-01
#  1.46232320e-01 7.60408064e-02 3.95412193e-02 2.05614341e-02
#  1.06919457e-02 5.55981177e-03 2.89110212e-03 1.50337310e-03
#  7.81754013e-04 4.06512087e-04 2.11386285e-04 1.09920868e-04
#  5.71588515e-05 2.97226028e-05 1.54557534e-05 8.03699179e-06
#  4.17923573e-06 2.17320258e-06 1.13006534e-06 5.87633978e-07
#  3.05569668e-07]

# %%
#畫出目標函數x*x
plt.plot(t, func(t), c='b')
#畫出一階導數之值
plt.scatter(x, func(x), c='r', )    
#畫出一階導數連線
plt.plot(x, func(x), c='r', label='lr={}'.format(lr))    
plt.legend()
plt.show()
